# %%
# -*- coding: utf-8 -*-
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#    http://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or
# implied.
# See the License for the specific language governing permissions and
# limitations under the License.
#

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# Data prišli vo formáte, ktorom neboli dáta rozdelené ',', ale '\t' tabulátorom

# %%
measurments = pd.read_csv('./data/measurements.csv',delimiter='\t')
measurments
# Out:
#        longitude       CO      CFCs      NOx  warning      NH3  latitude  \
# 0      -76.43941  9.46865  74.15057  6.16649      1.0  8.82096  39.33427
# 1       37.49338  5.47663  63.61956  9.45736      1.0  7.82746  55.62047
# 2      122.05228  9.85715  55.88937  9.22296      0.0  7.18582  37.19723
# 3       79.41727  6.21347  68.96604  6.51001      0.0  7.50511  12.25282
# 4      -42.19667  7.54374  61.93949  8.30137      1.0  9.69502 -21.41222
# ...          ...      ...       ...      ...      ...      ...       ...
# 12153   85.83334  8.85382  63.05060  6.52608      1.0  5.57966  20.88197
# 12154  -74.96933  9.57076  74.59498  6.40989      1.0  7.46766  39.71734
# 12155  -73.20483  8.04112  58.35228  8.00848      0.0  7.79391  41.16704
# 12156  -75.23266  6.40452  67.80306  6.61265      1.0  8.99481  43.10090
# 12157   -5.22126  5.23341  60.28862  5.58981      1.0  7.74560  33.43443
#
#              O3        Pb      H2CO      SO2     PM10     PAHs   C2H3NO5  \
# ...

# %%
stations = pd.read_csv('./data/stations.csv',delimiter='\t')
staons
# Out:
#      code  latitude              revision  longitude           location  \
# 0      FR  43.67681            2014/08/22    4.63031       Europe/Paris
# 1      GB  55.82737           01 Nov 2019   -4.05730      Europe/London
# 2      SK  48.43174  08/08/2017, 00:00:00   17.80310  Europe/Bratislava
# 3      IT  40.53123  11/11/2013, 00:00:00   17.58522        Europe/Rome
# 4      CN  35.85000  09/06/2013, 00:00:00  117.70000      Asia/Shanghai
# ...   ...       ...                   ...        ...                ...
# 1017   US  33.50921  12/20/2019, 00:00:00 -111.89903    America/Phoenix
# 1018   DE  50.23019  11/02/2013, 00:00:00    8.77155      Europe/Berlin
# 1019   GB  51.62907  12/03/2019, 00:00:00   -0.74934      Europe/London
# 1020   RU  55.64776            2019/04/10   38.02486      Europe/Moscow
# 1021   PE -16.25000            2016/12/27  -69.08333       America/Lima
#
#               QoS
# 0           accep
# 1       excellent
# 2           accep
# 3       maitennce
# ...

# %% [markdown]
# # Základný opis dát a ich charakteristiky

# %% [markdown]
# **Počet záznamov, počet atribútov a ich typy**

# %% [markdown]
# Počet záznamov pre measurments je **12158** a počet atribútov je **18**
#
# Počet záznamov pre stations je **1022** a počet atribútov je **6**
#
# Tieto informácie je vidieť pri výpise tabuliek

# %%
measurments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12158 entries, 0 to 12157
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   longitude  12158 non-null  float64
#  1   CO         12110 non-null  float64
#  2   CFCs       12110 non-null  float64
#  3   NOx        12110 non-null  float64
#  4   warning    12110 non-null  float64
#  5   NH3        12107 non-null  float64
#  6   latitude   12158 non-null  float64
#  7   O3         12110 non-null  float64
#  8   Pb         12109 non-null  float64
#  9   H2CO       12110 non-null  float64
#  10  SO2        12109 non-null  float64
#  11  PM10       12108 non-null  float64
#  12  PAHs       12109 non-null  float64
#  13  C2H3NO5    12109 non-null  float64
#  14  CH4        12109 non-null  float64
#  15  TEMP       12109 non-null  float64
#  16  PM2.5      12110 non-null  float64
#  17  PRES       12158 non-null  float64
# dtypes: float64(18)
# memory usage: 1.7 MB

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   code       1022 non-null   object
#  1   latitude   1022 non-null   float64
#  2   revision   1022 non-null   object
#  3   longitude  1022 non-null   float64
#  4   location   1022 non-null   object
#  5   QoS        1022 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 48.0+ KB

# %% [markdown]
# **Pre zvolené významné atribúty ich distribúcie, základné deskriptívne štatistiky...**

# %%
measurments.describe()
# Out:
#           longitude            CO          CFCs           NOx       warning  \
# count  12158.000000  12110.000000  12110.000000  12110.000000  12110.000000
# mean      13.303835      7.490057     68.175791      7.225295      0.593559
# std       72.037724      2.007101      7.692495      1.970283      0.491189
# min     -156.474320      0.314190      0.000000      0.714080      0.000000
# 25%      -50.195560      5.997122     63.047110      5.789568      0.000000
# 50%       10.302150      7.386760     68.141005      7.085990      1.000000
# 75%       72.939240      8.894837     73.400347      8.566017      1.000000
# max      178.004170     17.877720    100.000000     15.159810      1.000000
#
#                 NH3      latitude            O3            Pb          H2CO  \
# count  12107.000000  12158.000000  12110.000000  12109.000000  12110.000000
# mean       7.757563     30.409970      7.509404     47.859191     44.063891
# ...

# %% [markdown]
# **Párová analýza dát - vzťahy medzi dvojicami atribútov**

# %% [markdown]
# **Párová analýza dát - závislosti medzi dvojicami atribútov**

# %% [markdown]
# **Párová analýza dát - závislosti medzi predikovanou premennou a ostatnými premennými (potencionálny prediktor)**

# %% [markdown]
# stations.groupby('QoS').count()

# %% [markdown]
# Accep a Acceptable budú pravdepodobne rovnaké hodnoty ako aj maintenance a maitennce

# %% [markdown]
# Pravedepodbne v stations treba zmenit aj dátumy, ktoré majú aj hodinové záznamy iba na date

# %%
t= measurments.columns.tolist()
t.remove('longitude')
t.remove('latitude')
t
# Out:
# ['CO',
#  'CFCs',
#  'NOx',
#  'warning',
#  'NH3',
#  'O3',
#  'Pb',
#  'H2CO',
#  'SO2',
#  'PM10',
#  'PAHs',
#  'C2H3NO5',
#  'CH4',
#  'TEMP',
#  'PM2.5',
#  'PRES']

# %%
measurments[t].corr()
# Out:
#                CO      CFCs       NOx   warning       NH3        O3        Pb  \
# CO       1.000000 -0.007274 -0.018971  0.006155  0.082906  0.487901 -0.003600
# CFCs    -0.007274  1.000000  0.005684  0.005184  0.004280 -0.006618 -0.012200
# NOx     -0.018971  0.005684  1.000000 -0.595915 -0.435122  0.018332  0.000965
# warning  0.006155  0.005184 -0.595915  1.000000  0.644520  0.009469 -0.007330
# NH3      0.082906  0.004280 -0.435122  0.644520  1.000000 -0.038505  0.001663
# O3       0.487901 -0.006618  0.018332  0.009469 -0.038505  1.000000 -0.014327
# Pb      -0.003600 -0.012200  0.000965 -0.007330  0.001663 -0.014327  1.000000
# H2CO    -0.015129  0.004451 -0.009660  0.007314  0.000840 -0.013902  0.000706
# SO2     -0.004489 -0.007857 -0.008725  0.001870  0.000121 -0.002556 -0.012114
# PM10     0.004264  0.001480  0.007535  0.008670  0.019617  0.011213  0.007218
# PAHs    -0.006713 -0.004683 -0.013575  0.007828 -0.000666 -0.007764 -0.005606
# ...

# %%
sns.heatmap(measurments[t[:10]].corr(), annot=True,cmap='RdYlGn')
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(data=measurments[t[:7]], hue='warning')

# %%
measurments[t[:len(t)-1]].boxplot()
# Out:
# <AxesSubplot: >

# %%
stations[stations.longitude==measurments.longitude.unique().tolist().append()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 stations[stations.longitude==measurments.longitude.unique().tolist()]
#
# File ~\Desktop\semester 7\IAU\iau\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\Desktop\semester 7\IAU\iau\lib\site-packages\pandas\core\arraylike.py:43, in OpsMixin.__eq__(self, other)
#      41 @unpack_zerodim_and_defer("__eq__")
#      42 def __eq__(self, other):
# ---> 43     return self._cmp_method(other, operator.eq)
#
# File ~\Desktop\semester 7\IAU\iau\lib\site-packages\pandas\core\series.py:6246, in Series._cmp_method(self, other, op)
#    6243 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
